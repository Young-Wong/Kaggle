# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

import gc
import time
import pickle
import seaborn as sns
from tqdm import tqdm
from itertools import product
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn import preprocessing 
from xgboost import plot_importance
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

def downcast_dtypes(df):
    float_cols = [c for c in df if df[c].dtype == "float64"]
    int_cols = [c for c in df if df[c].dtype in ["int64", "int32"]]
    df[float_cols] = df[float_cols].astype(np.float16)
    df[int_cols] = df[int_cols].astype(np.int16)
    return df

import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=3, releaselevel='final', serial=0)

# %%
# 将index设置为ID，以避免稍后删除它
test  = pd.read_csv('../FutureSales/input/test.csv').set_index('ID')
train = pd.read_csv('../FutureSales/input/sales_train.csv')

#删除特异值
train = train[train.item_price<100000]
train = train[train.item_cnt_day<1001]
#售价低于0,用中值填充
median = train[(train.shop_id==32)&(train.item_id==2973)&(train.date_block_num==4)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

#清除重复行
train.drop_duplicates(subset=["date","date_block_num","shop_id","item_id","item_price","item_cnt_day"],keep='first',inplace=True)

##有几家商店是彼此的复制品,修复训练集和测试集将其更改为同一商店编号
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

#清除训练集中在测试集中不存在的商店
train = train.merge(test[['shop_id']].drop_duplicates(), how = 'inner')

# %%
#shops.csv数据--------------------------------------------------
shops = pd.read_csv('../FutureSales/input/shops.csv')
#分解出商店所在城市
shops.loc[shops.shop_name == 'Сергиев Посад ТЦ "7Я"', 'shop_name'] = 'СергиевПосад ТЦ "7Я"'
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'
shops['shop_city'] = LabelEncoder().fit_transform(shops['city'])
#分解出商店经营类型
shops['shop_name1'] = shops['shop_name'].apply(lambda x: x.lower()).str.replace('[^\w\s]', '').str.replace('\d+','').str.strip()
shops['shop_type'] = shops['shop_name1'].apply(lambda x: 'мтрц' if 'мтрц' in x else 'трц' if 'трц' in x else 'трк' if 'трк' in x else 'тц' if 'тц' in x else 'тк' if 'тк' in x else 'NO_DATA')
shops["shop_type"] = shops["shop_type"].map({'NO_DATA': 0 ,'мтрц': 1 ,'тк': 2 ,'трк': 3 ,'трц': 4 ,'тц': 5 })
#更新数据
shops = shops[['shop_id','shop_city','shop_type']]

#item_categories.csv数据--------------------------------------------------
cats = pd.read_csv('../FutureSales/input/item_categories.csv')
#分解出商品所在类别
cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['item_type'] = LabelEncoder().fit_transform(cats['type'])
# # 如果子类型是nan，就输入
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['item_subtype'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','item_type','item_subtype']]

#items.csv数据--------------------------------------------------
items = pd.read_csv('../FutureSales/input/items.csv')

items['name_1'], items['name_2'] = items['item_name'].str.split('[', 1).str
items['name_1'], items['name_3'] = items['item_name'].str.split('(', 1).str

items['name_2'] = items['name_2'].str.replace('[^A-Za-z0-9А-Яа-я]+', ' ').str.lower()
items['name_3'] = items['name_3'].str.replace('[^A-Za-z0-9А-Яа-я]+', ' ').str.lower()
items = items.fillna('0')

items['name_1'] = LabelEncoder().fit_transform(items['name_1'])
items['name_2'] = LabelEncoder().fit_transform(items['name_2'])
items['name_3'] = LabelEncoder().fit_transform(items['name_3'])

items = items[['item_id','item_category_id','name_1','name_2','name_3']]

# %% [markdown]
# 特征添加

# %%
#对于每个月，我们从该月的所有商店/项目组合创建一个网格
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in train['date_block_num'].unique():
    sales = train[train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)

#求每月在该商店该商品的售出量:item_cnt_month
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=cols, how='left')
matrix['item_cnt_month'] = (matrix['item_cnt_month'].fillna(0).clip(0,20).astype(np.float16))

#要使用时间技巧，请将测试对附加到矩阵中
test['date_block_num'] = 34
matrix = pd.concat([matrix, test], ignore_index=True, sort=False, keys=cols)
matrix.fillna(0, inplace=True) # 34 month
del test
gc.collect()
# Out:
# 45

# %%
matrix = pd.merge(matrix, shops, on=['shop_id'], how='left')
matrix = pd.merge(matrix, items, on=['item_id'], how='left')
matrix = pd.merge(matrix, cats, on=['item_category_id'], how='left')

del shops,items,cats
gc.collect()
# Out:
# 111

# %%
#添加月,日变量
matrix['year']  =  matrix['date_block_num']/12+2013
matrix['month'] = matrix['date_block_num'] % 12
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix['days']  = matrix['month'].map(days).astype(np.int8)
matrix['year']  = matrix['year'].astype(np.int16)
print(matrix.shape)
matrix.head(3)
# Out:
# (8860658, 15)
#    date_block_num  shop_id  item_id  item_cnt_month  shop_city  shop_type  \
# 0               0        2       19             0.0          0          5
# 1               0        2       27             1.0          0          5
# 2               0        2       28             0.0          0          5
#
#    item_category_id  name_1  name_2  name_3  item_type  item_subtype  year  \
# 0                40      19       4      42         11             4  2013
# 1                19      27      77      42          5            10  2013
# 2                30      28     108      42          8            55  2013
#
#    month  days
# 0      0    31
# 1      0    31
# 2      0    31

# %%
def lag_feature(df, lags, col):
    tmp = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id', col+'_lag_'+str(i)]
        shifted['date_block_num'] += i
        df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

def tianjia1(list_names,list_num):
    global matrix
    str1 = list_names[0]
    for i in range(1,len(list_names)):
        str1 = str1+'_and_'+list_names[i]
    str1 = str1+'_avg_item_cnt'
    
    group = matrix.groupby(list_names).agg({'item_cnt_month': ['mean']})
    group.columns = [str1]
    group.reset_index(inplace=True)

    matrix = pd.merge(matrix, group, on=list_names, how='left')
    matrix[str1] = matrix[str1].astype(np.float16)
    matrix = lag_feature(matrix, list_num, str1)
    matrix.drop([str1], axis=1, inplace=True)

# %%
#1时间item_cnt_month_lag
matrix = lag_feature(matrix, [1,2,3], 'item_cnt_month')

tianjia1(['date_block_num'],[1])

tianjia1(['date_block_num', 'item_id'],[1,2,3])
tianjia1(['date_block_num', 'shop_id'],[1,2,3])

tianjia1(['date_block_num', 'item_category_id'],[1])
tianjia1(['date_block_num', 'shop_id', 'item_category_id'],[1])
tianjia1(['date_block_num', 'shop_id', 'item_id'],[1])

print(matrix.shape)
matrix.head(3)
# Out:
# (8860658, 28)
#    date_block_num  shop_id  item_id  item_cnt_month  shop_city  shop_type  \
# 0               0        2       19             0.0          0          5
# 1               0        2       27             1.0          0          5
# 2               0        2       28             0.0          0          5
#
#    item_category_id  name_1  name_2  name_3  item_type  item_subtype  year  \
# 0                40      19       4      42         11             4  2013
# 1                19      27      77      42          5            10  2013
# 2                30      28     108      42          8            55  2013
#
#    month  days  item_cnt_month_lag_1  item_cnt_month_lag_2  \
# 0      0    31                   NaN                   NaN
# 1      0    31                   NaN                   NaN
# 2      0    31                   NaN                   NaN
#
#    item_cnt_month_lag_3  date_block_num_avg_item_cnt_lag_1  \
# 0                   NaN                                NaN
# 1                   NaN                                NaN
# 2                   NaN                                NaN
#
#    date_block_num_and_item_id_avg_item_cnt_lag_1  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_item_id_avg_item_cnt_lag_2  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_item_id_avg_item_cnt_lag_3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_shop_id_avg_item_cnt_lag_1  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_shop_id_avg_item_cnt_lag_2  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_shop_id_avg_item_cnt_lag_3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_item_category_id_avg_item_cnt_lag_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN

# %%
group = train.groupby(['item_id']).agg({'item_price': ['mean']})
group.columns = ['item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['item_id'], how='left')
matrix['item_avg_item_price'] = matrix['item_avg_item_price'].astype(np.float16)

group = train.groupby(['date_block_num','item_id']).agg({'item_price': ['mean']})
group.columns = ['date_item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix['date_item_avg_item_price'] = matrix['date_item_avg_item_price'].astype(np.float16)

lags = [1,2,3,4,5,6]
matrix = lag_feature(matrix, lags, 'date_item_avg_item_price')

for i in lags:
    matrix['delta_price_lag_'+str(i)] = \
        (matrix['date_item_avg_item_price_lag_'+str(i)] - matrix['item_avg_item_price']) / matrix['item_avg_item_price']

def select_trend(row):
    for i in lags:
        if row['delta_price_lag_'+str(i)]:
            return row['delta_price_lag_'+str(i)]
    return 0
    
matrix['delta_price_lag'] = matrix.apply(select_trend, axis=1)
matrix['delta_price_lag'] = matrix['delta_price_lag'].astype(np.float16)
matrix['delta_price_lag'].fillna(0, inplace=True)

fetures_to_drop = ['item_avg_item_price', 'date_item_avg_item_price']
for i in lags:
    fetures_to_drop += ['date_item_avg_item_price_lag_'+str(i)]
    fetures_to_drop += ['delta_price_lag_'+str(i)]

matrix.drop(fetures_to_drop, axis=1, inplace=True)

# %%
ts = time.time()
cache = {}
matrix['item_shop_last_sale'] = -1
matrix['item_shop_last_sale'] = matrix['item_shop_last_sale'].astype(np.int8)
for idx, row in matrix.iterrows():    
    key = str(row.item_id)+' '+str(row.shop_id)
    if key not in cache:
        if row.item_cnt_month!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        matrix.at[idx, 'item_shop_last_sale'] = row.date_block_num - last_date_block_num
        cache[key] = row.date_block_num         

cache = {}
matrix['item_last_sale'] = -1
matrix['item_last_sale'] = matrix['item_last_sale'].astype(np.int8)
for idx, row in matrix.iterrows():    
    key = row.item_id
    if key not in cache:
        if row.item_cnt_month!=0:
            cache[key] = row.date_block_num
    else:
        last_date_block_num = cache[key]
        if row.date_block_num>last_date_block_num:
            matrix.at[idx, 'item_last_sale'] = row.date_block_num - last_date_block_num
            cache[key] = row.date_block_num         
time.time() - ts
# Out:
# 1569.3552000522614

# %%
matrix['item_first_sale'] = matrix['date_block_num'] - matrix.groupby('item_id')['date_block_num'].transform('min')

# %%
ts = time.time()
def fill_na(df):
    for col in df.columns:
        if ('_lag_' in col) & (df[col].isnull().any()):
            if ('item_cnt' in col):
                df[col].fillna(0, inplace=True)         
    return df
matrix = matrix[matrix.date_block_num >3]
matrix = fill_na(matrix)
matrix = downcast_dtypes(matrix)
time.time() - ts
print(matrix.shape)
matrix.head(3)
# Out:
# (7756739, 32)
#          date_block_num  shop_id  item_id  item_cnt_month  shop_city  \
# 1103919               4        2       27             0.0          0
# 1103920               4        2       28             0.0          0
# 1103921               4        2       29             0.0          0
#
#          shop_type  item_category_id  name_1  name_2  name_3  item_type  \
# 1103919          5                19      27      77      42          5
# 1103920          5                30      28     108      42          8
# 1103921          5                23      29     124      42          5
#
#          item_subtype  year  month  days  item_cnt_month_lag_1  \
# 1103919            10  2013      4    31                   0.0
# 1103920            55  2013      4    31                   0.0
# 1103921            16  2013      4    31                   0.0
#
#          item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 1103919                   0.0                   0.0
# 1103920                   0.0                   0.0
# 1103921                   0.0                   0.0
#
#          date_block_num_avg_item_cnt_lag_1  \
# 1103919                           0.292969
# 1103920                           0.292969
# 1103921                           0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                       0.027771
# 1103920                                       0.111084
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_2  \
# 1103919                                       0.083313
# 1103920                                       0.083313
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_3  \
# 1103919                                       0.083313
# 1103920                                       0.194458
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_1  \
# 1103919                                       0.076233
# 1103920                                       0.076233
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_2  \
# 1103919                                       0.095459
# 1103920                                       0.095459
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_3  \
# 1103919                                       0.063599
# 1103920                                       0.063599
# 1103921                                       0.000000
#
#          date_block_num_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.743652
# 1103920                                           1.081055
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.500000
# 1103920                                           0.399902
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                                0.0
# 1103920                                                0.0
# 1103921                                                0.0
#
#          delta_price_lag  item_shop_last_sale  item_last_sale  item_first_sale
# 1103919         0.345459                    1               1                4
# 1103920         0.259521                   -1               1                4
# 1103921         0.000000                   -1               4                4

# %%
matrix.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month', 'shop_city',
#        'shop_type', 'item_category_id', 'name_1', 'name_2', 'name_3',
#        'item_type', 'item_subtype', 'year', 'month', 'days',
#        'item_cnt_month_lag_1', 'item_cnt_month_lag_2', 'item_cnt_month_lag_3',
#        'date_block_num_avg_item_cnt_lag_1',
#        'date_block_num_and_item_id_avg_item_cnt_lag_1',
#        'date_block_num_and_item_id_avg_item_cnt_lag_2',
#        'date_block_num_and_item_id_avg_item_cnt_lag_3',
#        'date_block_num_and_shop_id_avg_item_cnt_lag_1',
#        'date_block_num_and_shop_id_avg_item_cnt_lag_2',
#        'date_block_num_and_shop_id_avg_item_cnt_lag_3',
#        'date_block_num_and_item_category_id_avg_item_cnt_lag_1',
#        'date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1',
#        'date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1',
#        'delta_price_lag', 'item_shop_last_sale', 'item_last_sale',
#        'item_first_sale'],
#       dtype='object')

# %%
matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7756739 entries, 1103919 to 8860657
# Data columns (total 32 columns):
# date_block_num                                                        int16
# shop_id                                                               int16
# item_id                                                               int16
# item_cnt_month                                                        float16
# shop_city                                                             int16
# shop_type                                                             int16
# item_category_id                                                      int16
# name_1                                                                int16
# name_2                                                                int16
# name_3                                                                int16
# item_type                                                             int16
# item_subtype                                                          int16
# year                                                                  int16
# month                                                                 int16
# days                                                                  int8
# item_cnt_month_lag_1                                                  float16
# item_cnt_month_lag_2                                                  float16
# item_cnt_month_lag_3                                                  float16
# date_block_num_avg_item_cnt_lag_1                                     float16
# date_block_num_and_item_id_avg_item_cnt_lag_1                         float16
# date_block_num_and_item_id_avg_item_cnt_lag_2                         float16
# date_block_num_and_item_id_avg_item_cnt_lag_3                         float16
# date_block_num_and_shop_id_avg_item_cnt_lag_1                         float16
# date_block_num_and_shop_id_avg_item_cnt_lag_2                         float16
# date_block_num_and_shop_id_avg_item_cnt_lag_3                         float16
# date_block_num_and_item_category_id_avg_item_cnt_lag_1                float16
# date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1    float16
# date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1             float16
# delta_price_lag                                                       float16
# item_shop_last_sale                                                   int8
# item_last_sale                                                        int8
# item_first_sale                                                       int16
# dtypes: float16(15), int16(14), int8(3)
# memory usage: 510.4 MB

# %%
matrix.to_pickle('data2.pkl')
del matrix
gc.collect()
# Out:
# 41

# %%
data = pd.read_pickle('data2.pkl')
data = data[[
    'date_block_num', 
    'shop_id', 
    'item_id', 
    'item_cnt_month', 
#     'shop_city',
    'shop_type', 
    'item_category_id',
#     'item_type', 
    'name_1',
    'name_2',
    'name_3',
    'item_subtype',
    'year',
    'month',
    'days', 
    'item_cnt_month_lag_1', 
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3', 
    'date_block_num_avg_item_cnt_lag_1',
    'date_block_num_and_item_id_avg_item_cnt_lag_1',
    'date_block_num_and_item_id_avg_item_cnt_lag_2',
    'date_block_num_and_item_id_avg_item_cnt_lag_3',
    'date_block_num_and_shop_id_avg_item_cnt_lag_1',
    'date_block_num_and_shop_id_avg_item_cnt_lag_2',
    'date_block_num_and_shop_id_avg_item_cnt_lag_3',
    'date_block_num_and_item_category_id_avg_item_cnt_lag_1',
    'date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1',
    'date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1',
    'delta_price_lag', 
    'item_shop_last_sale', 
    'item_last_sale',
    'item_first_sale'
]]




X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']

X_zong = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_zong = data[data.date_block_num < 33]['item_cnt_month']

# 总得切分一下数据咯（训练集和测试集）
X_train, X_test, y_train, y_test = train_test_split(X_valid,Y_valid,test_size = 0.25)

X_tests = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

xx = pd.concat([X_zong,X_train])
yy = pd.concat([Y_zong,y_train])

del data,X_valid,Y_valid,X_train,y_train,X_zong,Y_zong
gc.collect()
# Out:
# 7

# %%
print(xx.shape)
xx.head(3)
# Out:
# (7487088, 29)
#          date_block_num  shop_id  item_id  shop_type  item_category_id  \
# 1103919               4        2       27          5                19
# 1103920               4        2       28          5                30
# 1103921               4        2       29          5                23
#
#          name_1  name_2  name_3  item_subtype  year  month  days  \
# 1103919      27      77      42            10  2013      4    31
# 1103920      28     108      42            55  2013      4    31
# 1103921      29     124      42            16  2013      4    31
#
#          item_cnt_month_lag_1  item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 1103919                   0.0                   0.0                   0.0
# 1103920                   0.0                   0.0                   0.0
# 1103921                   0.0                   0.0                   0.0
#
#          date_block_num_avg_item_cnt_lag_1  \
# 1103919                           0.292969
# 1103920                           0.292969
# 1103921                           0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                       0.027771
# 1103920                                       0.111084
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_2  \
# 1103919                                       0.083313
# 1103920                                       0.083313
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_3  \
# 1103919                                       0.083313
# 1103920                                       0.194458
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_1  \
# 1103919                                       0.076233
# 1103920                                       0.076233
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_2  \
# 1103919                                       0.095459
# 1103920                                       0.095459
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_3  \
# 1103919                                       0.063599
# 1103920                                       0.063599
# 1103921                                       0.000000
#
#          date_block_num_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.743652
# 1103920                                           1.081055
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.500000
# 1103920                                           0.399902
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                                0.0
# 1103920                                                0.0
# 1103921                                                0.0
#
#          delta_price_lag  item_shop_last_sale  item_last_sale  item_first_sale
# 1103919         0.345459                    1               1                4
# 1103920         0.259521                   -1               1                4
# 1103921         0.000000                   -1               4                4

# %%
xx.to_pickle('xx.pkl')
yy.to_pickle('yy.pkl')

X_test.to_pickle('X_test.pkl')
y_test.to_pickle('y_test.pkl')

# %%
ts = time.time()
model = XGBRegressor(
    max_depth=10,
    n_estimators=100,
    min_child_weight=0.5, 
    colsample_bytree=0.9, 
    subsample=0.8, 
    num_round = 10000,
    nthread = 16,
    eta=0.1,
    seed=1)

model.fit(xx, yy, eval_metric="rmse", eval_set=[(xx,yy),(X_test,y_test)], verbose=True, early_stopping_rounds = 10)
time.time() - ts
# Out:
# C:\Users\yw009\AppData\Local\Continuum\anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [08:15:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [08:15:24] WARNING: src/learner.cc:686: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [0]	validation_0-rmse:1.18468	validation_1-rmse:1.08527
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.13905	validation_1-rmse:1.0453
# [2]	validation_0-rmse:1.09263	validation_1-rmse:1.0038
# [3]	validation_0-rmse:1.05417	validation_1-rmse:0.968817
# [4]	validation_0-rmse:1.02048	validation_1-rmse:0.938395
# [5]	validation_0-rmse:0.991504	validation_1-rmse:0.913957
# [6]	validation_0-rmse:0.967538	validation_1-rmse:0.894337
# [7]	validation_0-rmse:0.949094	validation_1-rmse:0.880134
# [8]	validation_0-rmse:0.930329	validation_1-rmse:0.864941
# [9]	validation_0-rmse:0.914904	validation_1-rmse:0.853605
# [10]	validation_0-rmse:0.901564	validation_1-rmse:0.842936
# [11]	validation_0-rmse:0.891348	validation_1-rmse:0.836508
# [12]	validation_0-rmse:0.881418	validation_1-rmse:0.829775
# [13]	validation_0-rmse:0.871945	validation_1-rmse:0.824789
# [14]	validation_0-rmse:0.864109	validation_1-rmse:0.820127
# [15]	validation_0-rmse:0.857797	validation_1-rmse:0.816155
# [16]	validation_0-rmse:0.851567	validation_1-rmse:0.812688
# [17]	validation_0-rmse:0.845734	validation_1-rmse:0.809224
# [18]	validation_0-rmse:0.841169	validation_1-rmse:0.806154
# [19]	validation_0-rmse:0.836506	validation_1-rmse:0.802892
# [20]	validation_0-rmse:0.831973	validation_1-rmse:0.799624
# [21]	validation_0-rmse:0.828494	validation_1-rmse:0.797258
# [22]	validation_0-rmse:0.82506	validation_1-rmse:0.795332
# [23]	validation_0-rmse:0.821846	validation_1-rmse:0.794237
# [24]	validation_0-rmse:0.819221	validation_1-rmse:0.793229
# [25]	validation_0-rmse:0.816655	validation_1-rmse:0.792073
# [26]	validation_0-rmse:0.814438	validation_1-rmse:0.791134
# [27]	validation_0-rmse:0.811534	validation_1-rmse:0.789749
# [28]	validation_0-rmse:0.809648	validation_1-rmse:0.789155
# [29]	validation_0-rmse:0.807604	validation_1-rmse:0.788293
# [30]	validation_0-rmse:0.805292	validation_1-rmse:0.786759
# [31]	validation_0-rmse:0.802984	validation_1-rmse:0.784302
# [32]	validation_0-rmse:0.801313	validation_1-rmse:0.783392
# [33]	validation_0-rmse:0.798883	validation_1-rmse:0.780823
# [34]	validation_0-rmse:0.796322	validation_1-rmse:0.781182
# [35]	validation_0-rmse:0.794151	validation_1-rmse:0.778853
# [36]	validation_0-rmse:0.792513	validation_1-rmse:0.777818
# [37]	validation_0-rmse:0.790787	validation_1-rmse:0.778109
# [38]	validation_0-rmse:0.789084	validation_1-rmse:0.77772
# [39]	validation_0-rmse:0.786726	validation_1-rmse:0.77709
# [40]	validation_0-rmse:0.785384	validation_1-rmse:0.775531
# [41]	validation_0-rmse:0.783827	validation_1-rmse:0.775103
# [42]	validation_0-rmse:0.782722	validation_1-rmse:0.774574
# [43]	validation_0-rmse:0.781511	validation_1-rmse:0.774007
# [44]	validation_0-rmse:0.780321	validation_1-rmse:0.773221
# [45]	validation_0-rmse:0.779177	validation_1-rmse:0.77251
# [46]	validation_0-rmse:0.777888	validation_1-rmse:0.772018
# [47]	validation_0-rmse:0.777158	validation_1-rmse:0.771839
# [48]	validation_0-rmse:0.776097	validation_1-rmse:0.771422
# [49]	validation_0-rmse:0.775383	validation_1-rmse:0.771057
# [50]	validation_0-rmse:0.774784	validation_1-rmse:0.770927
# [51]	validation_0-rmse:0.773582	validation_1-rmse:0.771147
# [52]	validation_0-rmse:0.77246	validation_1-rmse:0.77072
# [53]	validation_0-rmse:0.77162	validation_1-rmse:0.770116
# [54]	validation_0-rmse:0.770847	validation_1-rmse:0.769543
# [55]	validation_0-rmse:0.769924	validation_1-rmse:0.76923
# [56]	validation_0-rmse:0.769126	validation_1-rmse:0.769516
# [57]	validation_0-rmse:0.768641	validation_1-rmse:0.769258
# [58]	validation_0-rmse:0.76727	validation_1-rmse:0.769236
# [59]	validation_0-rmse:0.766748	validation_1-rmse:0.768968
# [60]	validation_0-rmse:0.765901	validation_1-rmse:0.768126
# [61]	validation_0-rmse:0.765222	validation_1-rmse:0.767654
# [62]	validation_0-rmse:0.764311	validation_1-rmse:0.767114
# [63]	validation_0-rmse:0.763185	validation_1-rmse:0.766714
# [64]	validation_0-rmse:0.762696	validation_1-rmse:0.766673
# [65]	validation_0-rmse:0.762003	validation_1-rmse:0.765919
# [66]	validation_0-rmse:0.760697	validation_1-rmse:0.764702
# [67]	validation_0-rmse:0.760058	validation_1-rmse:0.764206
# [68]	validation_0-rmse:0.759372	validation_1-rmse:0.763971
# [69]	validation_0-rmse:0.759027	validation_1-rmse:0.764023
# [70]	validation_0-rmse:0.758439	validation_1-rmse:0.764003
# [71]	validation_0-rmse:0.757745	validation_1-rmse:0.763595
# [72]	validation_0-rmse:0.756849	validation_1-rmse:0.762714
# [73]	validation_0-rmse:0.756451	validation_1-rmse:0.762375
# [74]	validation_0-rmse:0.756102	validation_1-rmse:0.76236
# [75]	validation_0-rmse:0.755328	validation_1-rmse:0.761452
# [76]	validation_0-rmse:0.754698	validation_1-rmse:0.761342
# [77]	validation_0-rmse:0.75409	validation_1-rmse:0.761051
# [78]	validation_0-rmse:0.753392	validation_1-rmse:0.760817
# [79]	validation_0-rmse:0.752754	validation_1-rmse:0.760918
# [80]	validation_0-rmse:0.752317	validation_1-rmse:0.760566
# [81]	validation_0-rmse:0.750767	validation_1-rmse:0.761258
# [82]	validation_0-rmse:0.748488	validation_1-rmse:0.758392
# [83]	validation_0-rmse:0.748067	validation_1-rmse:0.758358
# [84]	validation_0-rmse:0.747495	validation_1-rmse:0.757914
# [85]	validation_0-rmse:0.747204	validation_1-rmse:0.757942
# [86]	validation_0-rmse:0.746942	validation_1-rmse:0.757827
# [87]	validation_0-rmse:0.746412	validation_1-rmse:0.75752
# [88]	validation_0-rmse:0.745841	validation_1-rmse:0.757509
# [89]	validation_0-rmse:0.745577	validation_1-rmse:0.757075
# [90]	validation_0-rmse:0.74444	validation_1-rmse:0.755659
# [91]	validation_0-rmse:0.744076	validation_1-rmse:0.755447
# [92]	validation_0-rmse:0.743397	validation_1-rmse:0.755251
# [93]	validation_0-rmse:0.743024	validation_1-rmse:0.755274
# [94]	validation_0-rmse:0.742499	validation_1-rmse:0.754865
# [95]	validation_0-rmse:0.742145	validation_1-rmse:0.754889
# [96]	validation_0-rmse:0.741641	validation_1-rmse:0.754618
# [97]	validation_0-rmse:0.741221	validation_1-rmse:0.754642
# [98]	validation_0-rmse:0.740796	validation_1-rmse:0.754483
# [99]	validation_0-rmse:0.740418	validation_1-rmse:0.754356
# 1789.755900144577

# %%
Y_tests = model.predict(X_tests).clip(0, 20)

# %%
test  = pd.read_csv('../FutureSales/input/test.csv').set_index('ID')
submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_tests
})
submission.to_csv('xgb_submission1.csv', index=False)

# %%
plot_features(model, (10,14))
