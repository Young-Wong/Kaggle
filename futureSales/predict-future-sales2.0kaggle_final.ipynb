# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

import gc
import time
import pickle
import seaborn as sns
from tqdm import tqdm
from itertools import product
import matplotlib.pyplot as plt
from xgboost import XGBRegressor
from sklearn import preprocessing 
from xgboost import plot_importance
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

def downcast_dtypes(df):
    float_cols = [c for c in df if df[c].dtype == "float64"]
    int_cols = [c for c in df if df[c].dtype in ["int64", "int32"]]
    df[float_cols] = df[float_cols].astype(np.float16)
    df[int_cols] = df[int_cols].astype(np.int16)
    return df

import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=5, releaselevel='final', serial=0)

# %%
# 将index设置为ID，以避免稍后删除它
test  = pd.read_csv('../input/test.csv').set_index('ID')
train = pd.read_csv('../input/sales_train.csv')

#删除特异值
train = train[train.item_price<100000]
train = train[train.item_cnt_day<1001]
#售价低于0,用中值填充
median = train[(train.shop_id==32)&(train.item_id==2973)&(train.date_block_num==4)&(train.item_price>0)].item_price.median()
train.loc[train.item_price<0, 'item_price'] = median

#清除重复行
train.drop_duplicates(subset=["date","date_block_num","shop_id","item_id","item_price","item_cnt_day"],keep='first',inplace=True)

##有几家商店是彼此的复制品,修复训练集和测试集将其更改为同一商店编号
# Якутск Орджоникидзе, 56
train.loc[train.shop_id == 0, 'shop_id'] = 57
test.loc[test.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
train.loc[train.shop_id == 1, 'shop_id'] = 58
test.loc[test.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
train.loc[train.shop_id == 10, 'shop_id'] = 11
test.loc[test.shop_id == 10, 'shop_id'] = 11

#清除训练集中在测试集中不存在的商店
train = train.merge(test[['shop_id']].drop_duplicates(), how = 'inner')

# %%
#shops.csv数据--------------------------------------------------
shops = pd.read_csv('../input/shops.csv')
#分解出商店所在城市
shops.loc[shops.shop_name == 'Сергиев Посад ТЦ "7Я"', 'shop_name'] = 'СергиевПосад ТЦ "7Я"'
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'
shops['shop_city'] = LabelEncoder().fit_transform(shops['city'])
#分解出商店经营类型
shops['shop_name1'] = shops['shop_name'].apply(lambda x: x.lower()).str.replace('[^\w\s]', '').str.replace('\d+','').str.strip()
shops['shop_type'] = shops['shop_name1'].apply(lambda x: 'мтрц' if 'мтрц' in x else 'трц' if 'трц' in x else 'трк' if 'трк' in x else 'тц' if 'тц' in x else 'тк' if 'тк' in x else 'NO_DATA')
shops["shop_type"] = shops["shop_type"].map({'NO_DATA': 0 ,'мтрц': 1 ,'тк': 2 ,'трк': 3 ,'трц': 4 ,'тц': 5 })
#更新数据
shops = shops[['shop_id','shop_city','shop_type']]

#item_categories.csv数据--------------------------------------------------
cats = pd.read_csv('../input/item_categories.csv')
#分解出商品所在类别
cats['split'] = cats['item_category_name'].str.split('-')
cats['type'] = cats['split'].map(lambda x: x[0].strip())
cats['item_type'] = LabelEncoder().fit_transform(cats['type'])
# # 如果子类型是nan，就输入
cats['subtype'] = cats['split'].map(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
cats['item_subtype'] = LabelEncoder().fit_transform(cats['subtype'])
cats = cats[['item_category_id','item_type','item_subtype']]

#items.csv数据--------------------------------------------------
items = pd.read_csv('../input/items.csv')

items['name_1'], items['name_2'] = items['item_name'].str.split('[', 1).str
items['name_1'], items['name_3'] = items['item_name'].str.split('(', 1).str

items['name_2'] = items['name_2'].str.replace('[^A-Za-z0-9А-Яа-я]+', ' ').str.lower()
items['name_3'] = items['name_3'].str.replace('[^A-Za-z0-9А-Яа-я]+', ' ').str.lower()
items = items.fillna('0')

items['name_1'] = LabelEncoder().fit_transform(items['name_1'])
items['name_2'] = LabelEncoder().fit_transform(items['name_2'])
items['name_3'] = LabelEncoder().fit_transform(items['name_3'])

items = items[['item_id','item_category_id','name_1','name_2','name_3']]

# %% [markdown]
# 特征添加

# %%
#对于每个月，我们从该月的所有商店/项目组合创建一个网格
matrix = []
cols = ['date_block_num','shop_id','item_id']
for i in train['date_block_num'].unique():
    sales = train[train.date_block_num==i]
    matrix.append(np.array(list(product([i], sales.shop_id.unique(), sales.item_id.unique())), dtype='int16'))
matrix = pd.DataFrame(np.vstack(matrix), columns=cols)
matrix['date_block_num'] = matrix['date_block_num'].astype(np.int8)
matrix['shop_id'] = matrix['shop_id'].astype(np.int8)
matrix['item_id'] = matrix['item_id'].astype(np.int16)
matrix.sort_values(cols,inplace=True)

#求每月在该商店该商品的售出量:item_cnt_month
group = train.groupby(['date_block_num','shop_id','item_id']).agg({'item_cnt_day': ['sum']})
group.columns = ['item_cnt_month']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=cols, how='left')
matrix['item_cnt_month'] = (matrix['item_cnt_month'].fillna(0).clip(0,20).astype(np.float16))

#要使用时间技巧，请将测试对附加到矩阵中
test['date_block_num'] = 34
matrix = pd.concat([matrix, test], ignore_index=True, sort=False, keys=cols)
matrix.fillna(0, inplace=True) # 34 month
del test
gc.collect()
# Out:
# 17

# %%
matrix = pd.merge(matrix, shops, on=['shop_id'], how='left')
matrix = pd.merge(matrix, items, on=['item_id'], how='left')
matrix = pd.merge(matrix, cats, on=['item_category_id'], how='left')

del shops,items,cats
gc.collect()
# Out:
# 20

# %%
#添加月,日变量
matrix['year']  =  matrix['date_block_num']/12+2013
matrix['month'] = matrix['date_block_num'] % 12
days = pd.Series([31,28,31,30,31,30,31,31,30,31,30,31])
matrix['days']  = matrix['month'].map(days).astype(np.int8)
matrix['year']  = matrix['year'].astype(np.int16)
print(matrix.shape)
matrix.head(3)
# Out:
# (8860658, 15)
#    date_block_num  shop_id  item_id  item_cnt_month  shop_city  shop_type  \
# 0               0        2       19             0.0          0          5
# 1               0        2       27             1.0          0          5
# 2               0        2       28             0.0          0          5
#
#    item_category_id  name_1  name_2  name_3  item_type  item_subtype  year  \
# 0                40      19       4      42         11             4  2013
# 1                19      27      77      42          5            10  2013
# 2                30      28     108      42          8            55  2013
#
#    month  days
# 0      0    31
# 1      0    31
# 2      0    31

# %%
def lag_feature(df, lags, col):
    tmp = df[['date_block_num','shop_id','item_id',col]]
    for i in lags:
        shifted = tmp.copy()
        shifted.columns = ['date_block_num','shop_id','item_id', col+'_lag_'+str(i)]
        shifted['date_block_num'] += i
        df = pd.merge(df, shifted, on=['date_block_num','shop_id','item_id'], how='left')
    return df

def tianjia1(list_names,list_num):
    global matrix
    str1 = list_names[0]
    for i in range(1,len(list_names)):
        str1 = str1+'_and_'+list_names[i]
    str1 = str1+'_avg_item_cnt'
    
    group = matrix.groupby(list_names).agg({'item_cnt_month': ['mean']})
    group.columns = [str1]
    group.reset_index(inplace=True)

    matrix = pd.merge(matrix, group, on=list_names, how='left')
    matrix[str1] = matrix[str1].astype(np.float16)
    matrix = lag_feature(matrix, list_num, str1)
    matrix.drop([str1], axis=1, inplace=True)

# %%
#1时间item_cnt_month_lag
matrix = lag_feature(matrix, [1,2,3], 'item_cnt_month')

tianjia1(['date_block_num'],[1])

tianjia1(['date_block_num', 'item_id'],[1,2,3])
tianjia1(['date_block_num', 'shop_id'],[1,2,3])

tianjia1(['date_block_num', 'item_category_id'],[1])
tianjia1(['date_block_num', 'shop_id', 'item_category_id'],[1])
tianjia1(['date_block_num', 'shop_id', 'item_id'],[1])

print(matrix.shape)
matrix.head(3)
# Out:
# (8860658, 28)
#    date_block_num  shop_id  item_id  item_cnt_month  shop_city  shop_type  \
# 0               0        2       19             0.0          0          5
# 1               0        2       27             1.0          0          5
# 2               0        2       28             0.0          0          5
#
#    item_category_id  name_1  name_2  name_3  item_type  item_subtype  year  \
# 0                40      19       4      42         11             4  2013
# 1                19      27      77      42          5            10  2013
# 2                30      28     108      42          8            55  2013
#
#    month  days  item_cnt_month_lag_1  item_cnt_month_lag_2  \
# 0      0    31                   NaN                   NaN
# 1      0    31                   NaN                   NaN
# 2      0    31                   NaN                   NaN
#
#    item_cnt_month_lag_3  date_block_num_avg_item_cnt_lag_1  \
# 0                   NaN                                NaN
# 1                   NaN                                NaN
# 2                   NaN                                NaN
#
#    date_block_num_and_item_id_avg_item_cnt_lag_1  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_item_id_avg_item_cnt_lag_2  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_item_id_avg_item_cnt_lag_3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_shop_id_avg_item_cnt_lag_1  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_shop_id_avg_item_cnt_lag_2  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_shop_id_avg_item_cnt_lag_3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
#
#    date_block_num_and_item_category_id_avg_item_cnt_lag_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN

# %%
group = train.groupby(['item_id']).agg({'item_price': ['mean']})
group.columns = ['item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['item_id'], how='left')
matrix['item_avg_item_price'] = matrix['item_avg_item_price'].astype(np.float16)

group = train.groupby(['date_block_num','item_id']).agg({'item_price': ['mean']})
group.columns = ['date_item_avg_item_price']
group.reset_index(inplace=True)

matrix = pd.merge(matrix, group, on=['date_block_num','item_id'], how='left')
matrix['date_item_avg_item_price'] = matrix['date_item_avg_item_price'].astype(np.float16)

lags = [1,2,3,4,5,6]
matrix = lag_feature(matrix, lags, 'date_item_avg_item_price')

for i in lags:
    matrix['delta_price_lag_'+str(i)] = \
        (matrix['date_item_avg_item_price_lag_'+str(i)] - matrix['item_avg_item_price']) / matrix['item_avg_item_price']

def select_trend(row):
    for i in lags:
        if row['delta_price_lag_'+str(i)]:
            return row['delta_price_lag_'+str(i)]
    return 0
    
matrix['delta_price_lag'] = matrix.apply(select_trend, axis=1)
matrix['delta_price_lag'] = matrix['delta_price_lag'].astype(np.float16)
matrix['delta_price_lag'].fillna(0, inplace=True)

fetures_to_drop = ['item_avg_item_price', 'date_item_avg_item_price']
for i in lags:
    fetures_to_drop += ['date_item_avg_item_price_lag_'+str(i)]
    fetures_to_drop += ['delta_price_lag_'+str(i)]

matrix.drop(fetures_to_drop, axis=1, inplace=True)

# %% [markdown]
# ts = time.time()
# cache = {}
# matrix['item_shop_last_sale'] = -1
# matrix['item_shop_last_sale'] = matrix['item_shop_last_sale'].astype(np.int8)
# for idx, row in matrix.iterrows():
#     key = str(row.item_id)+' '+str(row.shop_id)
#     if key not in cache:
#         if row.item_cnt_month!=0:
#             cache[key] = row.date_block_num
#     else:
#         last_date_block_num = cache[key]
#         matrix.at[idx, 'item_shop_last_sale'] = row.date_block_num - last_date_block_num
#         cache[key] = row.date_block_num
#
# cache = {}
# matrix['item_last_sale'] = -1
# matrix['item_last_sale'] = matrix['item_last_sale'].astype(np.int8)
# for idx, row in matrix.iterrows():
#     key = row.item_id
#     if key not in cache:
#         if row.item_cnt_month!=0:
#             cache[key] = row.date_block_num
#     else:
#         last_date_block_num = cache[key]
#         if row.date_block_num>last_date_block_num:
#             matrix.at[idx, 'item_last_sale'] = row.date_block_num - last_date_block_num
#             cache[key] = row.date_block_num
# time.time() - ts

# %%
matrix['item_first_sale'] = matrix['date_block_num'] - matrix.groupby('item_id')['date_block_num'].transform('min')

# %%
ts = time.time()
def fill_na(df):
    for col in df.columns:
        if ('_lag_' in col) & (df[col].isnull().any()):
            if ('item_cnt' in col):
                df[col].fillna(0, inplace=True)         
    return df
matrix = matrix[matrix.date_block_num >3]
matrix = fill_na(matrix)
matrix = downcast_dtypes(matrix)
time.time() - ts
print(matrix.shape)
matrix.head(3)
# Out:
# (7756739, 30)
#          date_block_num  shop_id  item_id  item_cnt_month  shop_city  \
# 1103919               4        2       27             0.0          0
# 1103920               4        2       28             0.0          0
# 1103921               4        2       29             0.0          0
#
#          shop_type  item_category_id  name_1  name_2  name_3  item_type  \
# 1103919          5                19      27      77      42          5
# 1103920          5                30      28     108      42          8
# 1103921          5                23      29     124      42          5
#
#          item_subtype  year  month  days  item_cnt_month_lag_1  \
# 1103919            10  2013      4    31                   0.0
# 1103920            55  2013      4    31                   0.0
# 1103921            16  2013      4    31                   0.0
#
#          item_cnt_month_lag_2  item_cnt_month_lag_3  \
# 1103919                   0.0                   0.0
# 1103920                   0.0                   0.0
# 1103921                   0.0                   0.0
#
#          date_block_num_avg_item_cnt_lag_1  \
# 1103919                           0.292969
# 1103920                           0.292969
# 1103921                           0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                       0.027771
# 1103920                                       0.111084
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_2  \
# 1103919                                       0.083313
# 1103920                                       0.083313
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_3  \
# 1103919                                       0.083313
# 1103920                                       0.194458
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_1  \
# 1103919                                       0.076233
# 1103920                                       0.076233
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_2  \
# 1103919                                       0.095459
# 1103920                                       0.095459
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_3  \
# 1103919                                       0.063599
# 1103920                                       0.063599
# 1103921                                       0.000000
#
#          date_block_num_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.743652
# 1103920                                           1.081055
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.500000
# 1103920                                           0.399902
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                                0.0
# 1103920                                                0.0
# 1103921                                                0.0
#
#          delta_price_lag  item_first_sale
# 1103919         0.345459                4
# 1103920         0.259521                4
# 1103921         0.000000                4

# %%
matrix.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month', 'shop_city',
#        'shop_type', 'item_category_id', 'name_1', 'name_2', 'name_3',
#        'item_type', 'item_subtype', 'year', 'month', 'days',
#        'item_cnt_month_lag_1', 'item_cnt_month_lag_2', 'item_cnt_month_lag_3',
#        'date_block_num_avg_item_cnt_lag_1',
#        'date_block_num_and_item_id_avg_item_cnt_lag_1',
#        'date_block_num_and_item_id_avg_item_cnt_lag_2',
#        'date_block_num_and_item_id_avg_item_cnt_lag_3',
#        'date_block_num_and_shop_id_avg_item_cnt_lag_1',
#        'date_block_num_and_shop_id_avg_item_cnt_lag_2',
#        'date_block_num_and_shop_id_avg_item_cnt_lag_3',
#        'date_block_num_and_item_category_id_avg_item_cnt_lag_1',
#        'date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1',
#        'date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1',
#        'delta_price_lag', 'item_first_sale'],
#       dtype='object')

# %%
matrix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7756739 entries, 1103919 to 8860657
# Data columns (total 30 columns):
# date_block_num                                                        int16
# shop_id                                                               int16
# item_id                                                               int16
# item_cnt_month                                                        float16
# shop_city                                                             int16
# shop_type                                                             int16
# item_category_id                                                      int16
# name_1                                                                int16
# name_2                                                                int16
# name_3                                                                int16
# item_type                                                             int16
# item_subtype                                                          int16
# year                                                                  int16
# month                                                                 int16
# days                                                                  int8
# item_cnt_month_lag_1                                                  float16
# item_cnt_month_lag_2                                                  float16
# item_cnt_month_lag_3                                                  float16
# date_block_num_avg_item_cnt_lag_1                                     float16
# date_block_num_and_item_id_avg_item_cnt_lag_1                         float16
# date_block_num_and_item_id_avg_item_cnt_lag_2                         float16
# date_block_num_and_item_id_avg_item_cnt_lag_3                         float16
# date_block_num_and_shop_id_avg_item_cnt_lag_1                         float16
# date_block_num_and_shop_id_avg_item_cnt_lag_2                         float16
# date_block_num_and_shop_id_avg_item_cnt_lag_3                         float16
# date_block_num_and_item_category_id_avg_item_cnt_lag_1                float16
# date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1    float16
# date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1             float16
# delta_price_lag                                                       float16
# item_first_sale                                                       int16
# dtypes: float16(15), int16(14), int8(1)
# memory usage: 495.6 MB

# %%
matrix.to_pickle('data_best.pkl')
del matrix
gc.collect()
# Out:
# 0

# %%
data = pd.read_pickle('data_best.pkl')
data = data[[
    'date_block_num', 
    'shop_id', 
    'item_id', 
    'item_cnt_month', 
     'shop_city',
    'shop_type', 
    'item_category_id',
     'item_type', 
    'name_1',
    'name_2',
    'name_3',
    'item_subtype',
    'year',
    'month',
    'days', 
    'item_cnt_month_lag_1', 
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3', 
    'date_block_num_avg_item_cnt_lag_1',
    'date_block_num_and_item_id_avg_item_cnt_lag_1',
    'date_block_num_and_item_id_avg_item_cnt_lag_2',
    'date_block_num_and_item_id_avg_item_cnt_lag_3',
    'date_block_num_and_shop_id_avg_item_cnt_lag_1',
    'date_block_num_and_shop_id_avg_item_cnt_lag_2',
    'date_block_num_and_shop_id_avg_item_cnt_lag_3',
    'date_block_num_and_item_category_id_avg_item_cnt_lag_1',
    'date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1',
    'date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1',
    'delta_price_lag', 
#    'item_shop_last_sale', 
#    'item_last_sale',
    'item_first_sale'
]]




X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']

X_zong = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_zong = data[data.date_block_num < 33]['item_cnt_month']

# 总得切分一下数据咯（训练集和测试集）
X_train, X_test, y_train, y_test = train_test_split(X_valid,Y_valid,test_size = 0.25)

X_tests = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

xx = pd.concat([X_zong,X_train])
yy = pd.concat([Y_zong,y_train])

del data, X_train,y_train,X_zong,Y_zong
gc.collect()
# Out:
# 93

# %%
print(xx.shape)
xx.head(3)
# Out:
# (7487088, 29)
#          date_block_num  shop_id  item_id  shop_city  shop_type  \
# 1103919               4        2       27          0          5
# 1103920               4        2       28          0          5
# 1103921               4        2       29          0          5
#
#          item_category_id  item_type  name_1  name_2  name_3  item_subtype  \
# 1103919                19          5      27      77      42            10
# 1103920                30          8      28     108      42            55
# 1103921                23          5      29     124      42            16
#
#          year  month  days  item_cnt_month_lag_1  item_cnt_month_lag_2  \
# 1103919  2013      4    31                   0.0                   0.0
# 1103920  2013      4    31                   0.0                   0.0
# 1103921  2013      4    31                   0.0                   0.0
#
#          item_cnt_month_lag_3  date_block_num_avg_item_cnt_lag_1  \
# 1103919                   0.0                           0.292969
# 1103920                   0.0                           0.292969
# 1103921                   0.0                           0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                       0.027771
# 1103920                                       0.111084
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_2  \
# 1103919                                       0.083313
# 1103920                                       0.083313
# 1103921                                       0.000000
#
#          date_block_num_and_item_id_avg_item_cnt_lag_3  \
# 1103919                                       0.083313
# 1103920                                       0.194458
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_1  \
# 1103919                                       0.076233
# 1103920                                       0.076233
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_2  \
# 1103919                                       0.095459
# 1103920                                       0.095459
# 1103921                                       0.000000
#
#          date_block_num_and_shop_id_avg_item_cnt_lag_3  \
# 1103919                                       0.063599
# 1103920                                       0.063599
# 1103921                                       0.000000
#
#          date_block_num_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.743652
# 1103920                                           1.081055
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_category_id_avg_item_cnt_lag_1  \
# 1103919                                           0.500000
# 1103920                                           0.399902
# 1103921                                           0.000000
#
#          date_block_num_and_shop_id_and_item_id_avg_item_cnt_lag_1  \
# 1103919                                                0.0
# 1103920                                                0.0
# 1103921                                                0.0
#
#          delta_price_lag  item_first_sale
# 1103919         0.345459                4
# 1103920         0.259521                4
# 1103921         0.000000                4

# %%
ts = time.time()
model = XGBRegressor(
    max_depth=10,
    n_estimators=1000,
    min_child_weight=0.5, 
    colsample_bytree=0.9, 
    subsample=0.8, 
    tree_method='gpu_hist',
    num_round = 10000,
    #nthread = 16,
    eta=0.1,
    seed=1)

model.fit(xx, yy, eval_metric="rmse", eval_set=[(xx,yy),(X_test,y_test)], verbose=True, early_stopping_rounds = 10)
time.time() - ts
# Out:
# [22:07:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.18534	validation_1-rmse:1.05905
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.13664	validation_1-rmse:1.01612
# [2]	validation_0-rmse:1.09163	validation_1-rmse:0.976923
# [3]	validation_0-rmse:1.05382	validation_1-rmse:0.945152
# [4]	validation_0-rmse:1.02116	validation_1-rmse:0.917697
# [5]	validation_0-rmse:0.9925	validation_1-rmse:0.893999
# [6]	validation_0-rmse:0.967918	validation_1-rmse:0.873814
# [7]	validation_0-rmse:0.948085	validation_1-rmse:0.857836
# [8]	validation_0-rmse:0.930036	validation_1-rmse:0.845618
# [9]	validation_0-rmse:0.913987	validation_1-rmse:0.832595
# [10]	validation_0-rmse:0.90059	validation_1-rmse:0.820954
# [11]	validation_0-rmse:0.890732	validation_1-rmse:0.815324
# [12]	validation_0-rmse:0.881239	validation_1-rmse:0.810587
# [13]	validation_0-rmse:0.87171	validation_1-rmse:0.802494
# [14]	validation_0-rmse:0.862771	validation_1-rmse:0.795868
# [15]	validation_0-rmse:0.857078	validation_1-rmse:0.792684
# [16]	validation_0-rmse:0.849769	validation_1-rmse:0.787551
# [17]	validation_0-rmse:0.843838	validation_1-rmse:0.784561
# [18]	validation_0-rmse:0.838288	validation_1-rmse:0.781074
# [19]	validation_0-rmse:0.833041	validation_1-rmse:0.777269
# [20]	validation_0-rmse:0.828761	validation_1-rmse:0.775786
# [21]	validation_0-rmse:0.824579	validation_1-rmse:0.773934
# [22]	validation_0-rmse:0.820366	validation_1-rmse:0.771521
# [23]	validation_0-rmse:0.817056	validation_1-rmse:0.769224
# [24]	validation_0-rmse:0.813506	validation_1-rmse:0.767276
# [25]	validation_0-rmse:0.808684	validation_1-rmse:0.765534
# [26]	validation_0-rmse:0.805816	validation_1-rmse:0.764289
# [27]	validation_0-rmse:0.802921	validation_1-rmse:0.762889
# [28]	validation_0-rmse:0.800407	validation_1-rmse:0.760993
# [29]	validation_0-rmse:0.797684	validation_1-rmse:0.760351
# [30]	validation_0-rmse:0.795402	validation_1-rmse:0.758353
# [31]	validation_0-rmse:0.793405	validation_1-rmse:0.755275
# [32]	validation_0-rmse:0.791527	validation_1-rmse:0.754235
# [33]	validation_0-rmse:0.789568	validation_1-rmse:0.75302
# [34]	validation_0-rmse:0.787884	validation_1-rmse:0.75241
# [35]	validation_0-rmse:0.786537	validation_1-rmse:0.751836
# [36]	validation_0-rmse:0.784893	validation_1-rmse:0.751
# [37]	validation_0-rmse:0.783211	validation_1-rmse:0.750701
# [38]	validation_0-rmse:0.781959	validation_1-rmse:0.750602
# [39]	validation_0-rmse:0.780648	validation_1-rmse:0.750254
# [40]	validation_0-rmse:0.779214	validation_1-rmse:0.75
# [41]	validation_0-rmse:0.778082	validation_1-rmse:0.749704
# [42]	validation_0-rmse:0.776716	validation_1-rmse:0.748601
# [43]	validation_0-rmse:0.775325	validation_1-rmse:0.748353
# [44]	validation_0-rmse:0.774158	validation_1-rmse:0.747512
# [45]	validation_0-rmse:0.772918	validation_1-rmse:0.746631
# [46]	validation_0-rmse:0.771835	validation_1-rmse:0.746236
# [47]	validation_0-rmse:0.770427	validation_1-rmse:0.745709
# [48]	validation_0-rmse:0.769523	validation_1-rmse:0.745284
# [49]	validation_0-rmse:0.768785	validation_1-rmse:0.744969
# [50]	validation_0-rmse:0.768038	validation_1-rmse:0.744631
# [51]	validation_0-rmse:0.767376	validation_1-rmse:0.744208
# [52]	validation_0-rmse:0.766369	validation_1-rmse:0.743885
# [53]	validation_0-rmse:0.765552	validation_1-rmse:0.743273
# [54]	validation_0-rmse:0.764888	validation_1-rmse:0.743419
# [55]	validation_0-rmse:0.764168	validation_1-rmse:0.743211
# [56]	validation_0-rmse:0.763396	validation_1-rmse:0.743176
# [57]	validation_0-rmse:0.762702	validation_1-rmse:0.743156
# [58]	validation_0-rmse:0.760749	validation_1-rmse:0.74096
# [59]	validation_0-rmse:0.759383	validation_1-rmse:0.740767
# [60]	validation_0-rmse:0.758804	validation_1-rmse:0.740667
# [61]	validation_0-rmse:0.757909	validation_1-rmse:0.740117
# [62]	validation_0-rmse:0.756782	validation_1-rmse:0.739031
# [63]	validation_0-rmse:0.756325	validation_1-rmse:0.738938
# [64]	validation_0-rmse:0.75563	validation_1-rmse:0.738566
# [65]	validation_0-rmse:0.755074	validation_1-rmse:0.738347
# [66]	validation_0-rmse:0.754262	validation_1-rmse:0.737505
# [67]	validation_0-rmse:0.753685	validation_1-rmse:0.737349
# [68]	validation_0-rmse:0.752887	validation_1-rmse:0.73726
# [69]	validation_0-rmse:0.752359	validation_1-rmse:0.737063
# [70]	validation_0-rmse:0.75133	validation_1-rmse:0.734982
# [71]	validation_0-rmse:0.750894	validation_1-rmse:0.73481
# [72]	validation_0-rmse:0.750277	validation_1-rmse:0.734678
# [73]	validation_0-rmse:0.749677	validation_1-rmse:0.734689
# [74]	validation_0-rmse:0.748904	validation_1-rmse:0.733519
# [75]	validation_0-rmse:0.748385	validation_1-rmse:0.733594
# [76]	validation_0-rmse:0.748098	validation_1-rmse:0.733274
# [77]	validation_0-rmse:0.747521	validation_1-rmse:0.733159
# [78]	validation_0-rmse:0.747047	validation_1-rmse:0.732933
# [79]	validation_0-rmse:0.746597	validation_1-rmse:0.732765
# [80]	validation_0-rmse:0.746161	validation_1-rmse:0.732674
# [81]	validation_0-rmse:0.74563	validation_1-rmse:0.732263
# [82]	validation_0-rmse:0.744904	validation_1-rmse:0.731708
# [83]	validation_0-rmse:0.744427	validation_1-rmse:0.731548
# [84]	validation_0-rmse:0.74198	validation_1-rmse:0.729189
# [85]	validation_0-rmse:0.741002	validation_1-rmse:0.728772
# [86]	validation_0-rmse:0.740198	validation_1-rmse:0.728597
# [87]	validation_0-rmse:0.739548	validation_1-rmse:0.728383
# [88]	validation_0-rmse:0.738992	validation_1-rmse:0.728002
# [89]	validation_0-rmse:0.73856	validation_1-rmse:0.727698
# [90]	validation_0-rmse:0.738072	validation_1-rmse:0.727583
# [91]	validation_0-rmse:0.737487	validation_1-rmse:0.727924
# [92]	validation_0-rmse:0.737014	validation_1-rmse:0.727642
# [93]	validation_0-rmse:0.736675	validation_1-rmse:0.727507
# [94]	validation_0-rmse:0.736114	validation_1-rmse:0.727189
# [95]	validation_0-rmse:0.73567	validation_1-rmse:0.727235
# [96]	validation_0-rmse:0.734752	validation_1-rmse:0.726457
# [97]	validation_0-rmse:0.734397	validation_1-rmse:0.726487
# [98]	validation_0-rmse:0.734135	validation_1-rmse:0.726504
# [99]	validation_0-rmse:0.733916	validation_1-rmse:0.726358
# [100]	validation_0-rmse:0.73364	validation_1-rmse:0.726345
# [101]	validation_0-rmse:0.733385	validation_1-rmse:0.726206
# [102]	validation_0-rmse:0.732986	validation_1-rmse:0.726282
# [103]	validation_0-rmse:0.732272	validation_1-rmse:0.725907
# [104]	validation_0-rmse:0.731983	validation_1-rmse:0.726073
# [105]	validation_0-rmse:0.731608	validation_1-rmse:0.72624
# [106]	validation_0-rmse:0.731357	validation_1-rmse:0.72617
# [107]	validation_0-rmse:0.73109	validation_1-rmse:0.726111
# [108]	validation_0-rmse:0.730623	validation_1-rmse:0.726184
# [109]	validation_0-rmse:0.730109	validation_1-rmse:0.726039
# [110]	validation_0-rmse:0.729216	validation_1-rmse:0.726367
# [111]	validation_0-rmse:0.728779	validation_1-rmse:0.726337
# [112]	validation_0-rmse:0.727094	validation_1-rmse:0.724122
# [113]	validation_0-rmse:0.726706	validation_1-rmse:0.72403
# [114]	validation_0-rmse:0.726364	validation_1-rmse:0.723966
# [115]	validation_0-rmse:0.726052	validation_1-rmse:0.723993
# [116]	validation_0-rmse:0.725493	validation_1-rmse:0.723979
# [117]	validation_0-rmse:0.725206	validation_1-rmse:0.723937
# [118]	validation_0-rmse:0.724367	validation_1-rmse:0.723956
# [119]	validation_0-rmse:0.724002	validation_1-rmse:0.723649
# [120]	validation_0-rmse:0.723146	validation_1-rmse:0.723285
# [121]	validation_0-rmse:0.722805	validation_1-rmse:0.723374
# [122]	validation_0-rmse:0.722309	validation_1-rmse:0.723292
# [123]	validation_0-rmse:0.722031	validation_1-rmse:0.723315
# [124]	validation_0-rmse:0.721781	validation_1-rmse:0.723348
# [125]	validation_0-rmse:0.721316	validation_1-rmse:0.723103
# [126]	validation_0-rmse:0.721058	validation_1-rmse:0.723015
# [127]	validation_0-rmse:0.720794	validation_1-rmse:0.723008
# [128]	validation_0-rmse:0.720442	validation_1-rmse:0.723362
# [129]	validation_0-rmse:0.720029	validation_1-rmse:0.722849
# [130]	validation_0-rmse:0.719775	validation_1-rmse:0.722913
# [131]	validation_0-rmse:0.719427	validation_1-rmse:0.722912
# [132]	validation_0-rmse:0.719097	validation_1-rmse:0.722908
# [133]	validation_0-rmse:0.718855	validation_1-rmse:0.722601
# [134]	validation_0-rmse:0.718489	validation_1-rmse:0.722594
# [135]	validation_0-rmse:0.718149	validation_1-rmse:0.722487
# [136]	validation_0-rmse:0.717466	validation_1-rmse:0.722395
# [137]	validation_0-rmse:0.716485	validation_1-rmse:0.721901
# [138]	validation_0-rmse:0.715665	validation_1-rmse:0.721806
# [139]	validation_0-rmse:0.715332	validation_1-rmse:0.72184
# [140]	validation_0-rmse:0.713858	validation_1-rmse:0.721206
# [141]	validation_0-rmse:0.713358	validation_1-rmse:0.721033
# [142]	validation_0-rmse:0.713152	validation_1-rmse:0.721097
# [143]	validation_0-rmse:0.712613	validation_1-rmse:0.720828
# [144]	validation_0-rmse:0.712149	validation_1-rmse:0.720544
# [145]	validation_0-rmse:0.711911	validation_1-rmse:0.720424
# [146]	validation_0-rmse:0.711331	validation_1-rmse:0.719971
# [147]	validation_0-rmse:0.710905	validation_1-rmse:0.719447
# [148]	validation_0-rmse:0.710585	validation_1-rmse:0.719427
# [149]	validation_0-rmse:0.709476	validation_1-rmse:0.71923
# [150]	validation_0-rmse:0.709319	validation_1-rmse:0.71917
# [151]	validation_0-rmse:0.709066	validation_1-rmse:0.719199
# [152]	validation_0-rmse:0.70885	validation_1-rmse:0.719133
# [153]	validation_0-rmse:0.708381	validation_1-rmse:0.719034
# [154]	validation_0-rmse:0.708049	validation_1-rmse:0.71908
# [155]	validation_0-rmse:0.707768	validation_1-rmse:0.719103
# [156]	validation_0-rmse:0.706637	validation_1-rmse:0.718901
# [157]	validation_0-rmse:0.706364	validation_1-rmse:0.718939
# [158]	validation_0-rmse:0.705996	validation_1-rmse:0.718589
# [159]	validation_0-rmse:0.705593	validation_1-rmse:0.718133
# [160]	validation_0-rmse:0.705353	validation_1-rmse:0.718132
# [161]	validation_0-rmse:0.70508	validation_1-rmse:0.717947
# [162]	validation_0-rmse:0.704894	validation_1-rmse:0.718033
# [163]	validation_0-rmse:0.70452	validation_1-rmse:0.717587
# [164]	validation_0-rmse:0.70425	validation_1-rmse:0.717475
# [165]	validation_0-rmse:0.702378	validation_1-rmse:0.716068
# [166]	validation_0-rmse:0.702056	validation_1-rmse:0.716184
# [167]	validation_0-rmse:0.701711	validation_1-rmse:0.716221
# [168]	validation_0-rmse:0.698793	validation_1-rmse:0.711436
# [169]	validation_0-rmse:0.698516	validation_1-rmse:0.711415
# [170]	validation_0-rmse:0.697983	validation_1-rmse:0.711412
# [171]	validation_0-rmse:0.696773	validation_1-rmse:0.711013
# [172]	validation_0-rmse:0.696603	validation_1-rmse:0.710971
# [173]	validation_0-rmse:0.696354	validation_1-rmse:0.711141
# [174]	validation_0-rmse:0.695493	validation_1-rmse:0.709372
# [175]	validation_0-rmse:0.6952	validation_1-rmse:0.709369
# [176]	validation_0-rmse:0.695032	validation_1-rmse:0.709368
# [177]	validation_0-rmse:0.694859	validation_1-rmse:0.709372
# [178]	validation_0-rmse:0.694683	validation_1-rmse:0.709351
# [179]	validation_0-rmse:0.694499	validation_1-rmse:0.709125
# [180]	validation_0-rmse:0.694038	validation_1-rmse:0.708983
# [181]	validation_0-rmse:0.693576	validation_1-rmse:0.708902
# [182]	validation_0-rmse:0.693387	validation_1-rmse:0.708849
# [183]	validation_0-rmse:0.693143	validation_1-rmse:0.708893
# [184]	validation_0-rmse:0.692867	validation_1-rmse:0.708886
# [185]	validation_0-rmse:0.692724	validation_1-rmse:0.708835
# [186]	validation_0-rmse:0.692178	validation_1-rmse:0.708466
# [187]	validation_0-rmse:0.691966	validation_1-rmse:0.708425
# [188]	validation_0-rmse:0.691747	validation_1-rmse:0.708396
# [189]	validation_0-rmse:0.69148	validation_1-rmse:0.708386
# [190]	validation_0-rmse:0.691184	validation_1-rmse:0.708266
# [191]	validation_0-rmse:0.690189	validation_1-rmse:0.707635
# [192]	validation_0-rmse:0.690046	validation_1-rmse:0.707662
# [193]	validation_0-rmse:0.689425	validation_1-rmse:0.707633
# [194]	validation_0-rmse:0.68874	validation_1-rmse:0.70741
# [195]	validation_0-rmse:0.688538	validation_1-rmse:0.70736
# [196]	validation_0-rmse:0.688232	validation_1-rmse:0.707277
# [197]	validation_0-rmse:0.687821	validation_1-rmse:0.70688
# [198]	validation_0-rmse:0.686702	validation_1-rmse:0.704979
# [199]	validation_0-rmse:0.686171	validation_1-rmse:0.704902
# [200]	validation_0-rmse:0.686006	validation_1-rmse:0.704936
# [201]	validation_0-rmse:0.685476	validation_1-rmse:0.704863
# [202]	validation_0-rmse:0.685228	validation_1-rmse:0.704876
# [203]	validation_0-rmse:0.684866	validation_1-rmse:0.704949
# [204]	validation_0-rmse:0.684663	validation_1-rmse:0.705028
# [205]	validation_0-rmse:0.684335	validation_1-rmse:0.704758
# [206]	validation_0-rmse:0.683977	validation_1-rmse:0.704731
# [207]	validation_0-rmse:0.683743	validation_1-rmse:0.704631
# [208]	validation_0-rmse:0.683518	validation_1-rmse:0.704652
# [209]	validation_0-rmse:0.683328	validation_1-rmse:0.704622
# [210]	validation_0-rmse:0.683173	validation_1-rmse:0.704631
# [211]	validation_0-rmse:0.682549	validation_1-rmse:0.704248
# [212]	validation_0-rmse:0.68218	validation_1-rmse:0.704287
# [213]	validation_0-rmse:0.682018	validation_1-rmse:0.704348
# [214]	validation_0-rmse:0.681643	validation_1-rmse:0.704255
# [215]	validation_0-rmse:0.680122	validation_1-rmse:0.700532
# [216]	validation_0-rmse:0.679849	validation_1-rmse:0.700428
# [217]	validation_0-rmse:0.679589	validation_1-rmse:0.700406
# [218]	validation_0-rmse:0.679087	validation_1-rmse:0.700481
# [219]	validation_0-rmse:0.678888	validation_1-rmse:0.700453
# [220]	validation_0-rmse:0.678685	validation_1-rmse:0.700341
# [221]	validation_0-rmse:0.678467	validation_1-rmse:0.700361
# [222]	validation_0-rmse:0.678316	validation_1-rmse:0.700411
# [223]	validation_0-rmse:0.677978	validation_1-rmse:0.700371
# [224]	validation_0-rmse:0.677256	validation_1-rmse:0.699776
# [225]	validation_0-rmse:0.676844	validation_1-rmse:0.699736
# [226]	validation_0-rmse:0.675856	validation_1-rmse:0.69903
# [227]	validation_0-rmse:0.675639	validation_1-rmse:0.698929
# [228]	validation_0-rmse:0.675134	validation_1-rmse:0.69687
# [229]	validation_0-rmse:0.674964	validation_1-rmse:0.696863
# [230]	validation_0-rmse:0.674766	validation_1-rmse:0.696814
# [231]	validation_0-rmse:0.674538	validation_1-rmse:0.696789
# [232]	validation_0-rmse:0.674352	validation_1-rmse:0.696745
# [233]	validation_0-rmse:0.67399	validation_1-rmse:0.696777
# [234]	validation_0-rmse:0.673646	validation_1-rmse:0.696749
# [235]	validation_0-rmse:0.673393	validation_1-rmse:0.696793
# [236]	validation_0-rmse:0.673156	validation_1-rmse:0.696728
# [237]	validation_0-rmse:0.672432	validation_1-rmse:0.696515
# [238]	validation_0-rmse:0.672209	validation_1-rmse:0.69668
# [239]	validation_0-rmse:0.671849	validation_1-rmse:0.696534
# [240]	validation_0-rmse:0.671599	validation_1-rmse:0.69655
# [241]	validation_0-rmse:0.671403	validation_1-rmse:0.696462
# [242]	validation_0-rmse:0.671194	validation_1-rmse:0.696551
# [243]	validation_0-rmse:0.670867	validation_1-rmse:0.696329
# [244]	validation_0-rmse:0.670589	validation_1-rmse:0.69632
# [245]	validation_0-rmse:0.670227	validation_1-rmse:0.696348
# [246]	validation_0-rmse:0.669817	validation_1-rmse:0.696358
# [247]	validation_0-rmse:0.669644	validation_1-rmse:0.696425
# [248]	validation_0-rmse:0.669241	validation_1-rmse:0.696524
# [249]	validation_0-rmse:0.669018	validation_1-rmse:0.696426
# [250]	validation_0-rmse:0.668768	validation_1-rmse:0.696441
# [251]	validation_0-rmse:0.668612	validation_1-rmse:0.696425
# [252]	validation_0-rmse:0.668297	validation_1-rmse:0.696553
# [253]	validation_0-rmse:0.667915	validation_1-rmse:0.696223
# [254]	validation_0-rmse:0.667319	validation_1-rmse:0.695972
# [255]	validation_0-rmse:0.667147	validation_1-rmse:0.695977
# [256]	validation_0-rmse:0.666881	validation_1-rmse:0.695976
# [257]	validation_0-rmse:0.666525	validation_1-rmse:0.696038
# [258]	validation_0-rmse:0.666351	validation_1-rmse:0.696313
# [259]	validation_0-rmse:0.666165	validation_1-rmse:0.696326
# [260]	validation_0-rmse:0.665856	validation_1-rmse:0.696338
# [261]	validation_0-rmse:0.665442	validation_1-rmse:0.696156
# [262]	validation_0-rmse:0.665266	validation_1-rmse:0.696046
# [263]	validation_0-rmse:0.665065	validation_1-rmse:0.696034
# [264]	validation_0-rmse:0.664958	validation_1-rmse:0.696055
# Stopping. Best iteration:
# [254]	validation_0-rmse:0.667319	validation_1-rmse:0.695972
# 78.12961077690125

# %% [markdown]
# [254]	validation_0-rmse:0.667319	validation_1-rmse:0.695972

# %%
Y_tests = model.predict(X_tests).clip(0, 20)

# %%
test  = pd.read_csv('../input/test.csv').set_index('ID')
submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_tests
})
submission.to_csv('xgb_submission_best_candidate.csv', index=False)

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
pickle.dump(Y_pred, open('laoshi_train.pickle', 'wb'))
pickle.dump(Y_valid, open('laoshi_valid_label.pickle', 'wb'))

# %%
plot_features(model, (10,14))
